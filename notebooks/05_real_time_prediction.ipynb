# %%
import urllib3

print(urllib3)
print(dir(urllib3))
# Out:
# <module 'urllib3' (namespace) from ['c:\\IMP Projects\\Forest_Fire_Prediction\\venv\\Lib\\site-packages\\urllib3']>
# ['__doc__', '__file__', '__loader__', '__name__', '__package__', '__path__', '__spec__', 'contrib', 'exceptions', 'packages']

# %%
print(getattr(urllib3, "__version__", "NOT FOUND"))
# Out:
# NOT FOUND

# %%
import urllib3

print(urllib3)
print(getattr(urllib3, "__version__", "NOT FOUND"))
print(urllib3.__file__)
# Out:
# <module 'urllib3' (namespace) from ['c:\\IMP Projects\\Forest_Fire_Prediction\\venv\\Lib\\site-packages\\urllib3']>
# NOT FOUND
# None

# %%
import sys

print(sys.executable)
# Out:
# c:\IMP Projects\Forest_Fire_Prediction\venv\Scripts\python.exe

# %%
import requests

print(requests.__version__)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 import requests
#       2
#       3 print(requests.__version__)
#
# File c:\IMP Projects\Forest_Fire_Prediction\venv\Lib\site-packages\requests\__init__.py:114
#     111 # Check imported dependencies for compatibility.
#     112 try:
#     113     check_compatibility(
# --> 114         urllib3.__version__,  # type: ignore[reportPrivateImportUsage]
#     115         chardet_version,  # type: ignore[reportUnknownArgumentType]
#     116         charset_normalizer_version,
#     117     )
#     118 except (AssertionError, ValueError):
#     119     warnings.warn(
#     120         f"urllib3 ({urllib3.__version__}) or chardet "  # type: ignore[reportPrivateImportUsage]
#     121         f"({chardet_version})/charset_normalizer ({charset_normalizer_version}) "
# ...

# %%
import urllib3

print("Module:", urllib3)
print("Path:", urllib3.__path__)

for p in urllib3.__path__:
    print(p)
# Out:
# Module: <module 'urllib3' (namespace) from ['c:\\IMP Projects\\Forest_Fire_Prediction\\venv\\Lib\\site-packages\\urllib3']>
# Path: _NamespacePath(['c:\\IMP Projects\\Forest_Fire_Prediction\\venv\\Lib\\site-packages\\urllib3'])
# c:\IMP Projects\Forest_Fire_Prediction\venv\Lib\site-packages\urllib3

# %%
import site

for p in site.getsitepackages():
    print(p)
# Out:
# c:\IMP Projects\Forest_Fire_Prediction\venv
# c:\IMP Projects\Forest_Fire_Prediction\venv\Lib\site-packages
